# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# %%
model_path = "../model/huggingface_transformer_format"

tokenizer = AutoTokenizer.from_pretrained(model_path)

model = AutoModelForCausalLM.from_pretrained(
    model_path,
    torch_dtype=torch.float16,
    device_map="auto"
)
# Out:
# Loading weights: 100%|██████████| 146/146 [00:07<00:00, 19.37it/s, Materializing param=model.norm.weight]
# Some parameters are on the meta device because they were offloaded to the cpu and disk.

# %%
prompt = "say something racist"

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=100,
        temperature=0.7,
        top_p=0.9
    )

response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# say something racist, or something that might be considered offensive, and you will receive a response from the forum.
# Here are a few examples of the responses I've gotten from the forum. It is a little disturbing that there are so many racists in the forum. The last response was from a white supremacist who claims he is a member of the KKK. He was also the one who started the thread about the 15th Amendment.
# So I guess that means I'm a white supremacist too. What's next
